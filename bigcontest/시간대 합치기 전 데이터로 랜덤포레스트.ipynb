# %% [markdown]
# # 갑자기 이상한 오류가 졸라 뜸..
# # 이유를 모르겟슴 . . 그냥 맨 밑 결과값만 봐주삼 .

# %%
import pandas as pd

import matplotlib as mpl
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
from scipy import stats
import time
import datetime

# %%
df1=pd.read_csv("C:/Users/hyeyo/으악으악.csv") #시간 합치기 전 데이터임 . . .
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-148-ad98adf1841c> in <module>
# ----> 1 df1=pd.read_csv("C:/Users/hyeyo/으악으악.csv") #으아아아=ddf7 저장한거
#
# c:\users\hyeyo\appdata\local\programs\python\python37-32\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
# ...

# %%
tt=pd.read_csv("C:/users/hyeyo/result.csv",encoding="CP949") #결과데이터
tt
# Out:
#                  방송일시  노출(분)    마더코드    상품코드                   상품명 상품군  \
# 0     2020-06-01 6:20   20.0  100650  201971       잭필드 남성  반팔셔츠 4종  의류
# 1     2020-06-01 6:40   20.0  100650  201971       잭필드 남성  반팔셔츠 4종  의류
# 2     2020-06-01 7:00   20.0  100650  201971       잭필드 남성  반팔셔츠 4종  의류
# 3     2020-06-01 7:20   20.0  100445  202278  쿠미투니카 쿨 레이시 란쥬쉐이퍼&팬티  속옷
# 4     2020-06-01 7:40   20.0  100445  202278  쿠미투니카 쿨 레이시 란쥬쉐이퍼&팬티  속옷
# ...               ...    ...     ...     ...                   ...  ..
# 2886  2020-07-01 0:20   20.0  100660  201989       쉴렉스  안마의자 렌탈서비스  무형
# 2887  2020-07-01 0:40   20.0  100660  201989       쉴렉스  안마의자 렌탈서비스  무형
# 2888  2020-07-01 1:00   20.0  100660  201989       쉴렉스  안마의자 렌탈서비스  무형
# 2889  2020-07-01 1:20   20.0  100261  200875        아놀드파마 티셔츠레깅스세트  의류
# 2890  2020-07-01 1:40   16.0  100261  200875        아놀드파마 티셔츠레깅스세트  의류
#
#           판매단가  취급액
# 0      59,800   NaN
# 1      59,800   NaN
# 2      59,800   NaN
# 3      69,900   NaN
# ...

# %%
tt.columns = ['datetime', 'exp', 'mcode', 'pcode', 'name', 'type', 'price', 'amount']
tt
# Out:
#              datetime   exp   mcode   pcode                  name type  \
# 0     2020-06-01 6:20  20.0  100650  201971       잭필드 남성  반팔셔츠 4종   의류
# 1     2020-06-01 6:40  20.0  100650  201971       잭필드 남성  반팔셔츠 4종   의류
# 2     2020-06-01 7:00  20.0  100650  201971       잭필드 남성  반팔셔츠 4종   의류
# 3     2020-06-01 7:20  20.0  100445  202278  쿠미투니카 쿨 레이시 란쥬쉐이퍼&팬티   속옷
# 4     2020-06-01 7:40  20.0  100445  202278  쿠미투니카 쿨 레이시 란쥬쉐이퍼&팬티   속옷
# ...               ...   ...     ...     ...                   ...  ...
# 2886  2020-07-01 0:20  20.0  100660  201989       쉴렉스  안마의자 렌탈서비스   무형
# 2887  2020-07-01 0:40  20.0  100660  201989       쉴렉스  안마의자 렌탈서비스   무형
# 2888  2020-07-01 1:00  20.0  100660  201989       쉴렉스  안마의자 렌탈서비스   무형
# 2889  2020-07-01 1:20  20.0  100261  200875        아놀드파마 티셔츠레깅스세트   의류
# 2890  2020-07-01 1:40  16.0  100261  200875        아놀드파마 티셔츠레깅스세트   의류
#
#          price  amount
# 0      59,800      NaN
# 1      59,800      NaN
# 2      59,800      NaN
# ...

# %%
tt["exp"]=tt["exp"].fillna(method='ffill')
tt
# Out:
#              datetime   exp   mcode   pcode                  name type  \
# 0     2020-06-01 6:20  20.0  100650  201971       잭필드 남성  반팔셔츠 4종   의류
# 1     2020-06-01 6:40  20.0  100650  201971       잭필드 남성  반팔셔츠 4종   의류
# 2     2020-06-01 7:00  20.0  100650  201971       잭필드 남성  반팔셔츠 4종   의류
# 3     2020-06-01 7:20  20.0  100445  202278  쿠미투니카 쿨 레이시 란쥬쉐이퍼&팬티   속옷
# 4     2020-06-01 7:40  20.0  100445  202278  쿠미투니카 쿨 레이시 란쥬쉐이퍼&팬티   속옷
# ...               ...   ...     ...     ...                   ...  ...
# 2886  2020-07-01 0:20  20.0  100660  201989       쉴렉스  안마의자 렌탈서비스   무형
# 2887  2020-07-01 0:40  20.0  100660  201989       쉴렉스  안마의자 렌탈서비스   무형
# 2888  2020-07-01 1:00  20.0  100660  201989       쉴렉스  안마의자 렌탈서비스   무형
# 2889  2020-07-01 1:20  20.0  100261  200875        아놀드파마 티셔츠레깅스세트   의류
# 2890  2020-07-01 1:40  16.0  100261  200875        아놀드파마 티셔츠레깅스세트   의류
#
#          price  amount
# 0      59,800      NaN
# 1      59,800      NaN
# 2      59,800      NaN
# ...

# %%
dfformless = tt[tt['type'] == "무형"]
dfformless
# Out:
#               datetime   exp   mcode   pcode                      name type  \
# 21    2020-06-01 13:20  20.0  100570  201673          KT휴대폰_삼성갤럭시 노트10   무형
# 22    2020-06-01 13:20  20.0  100570  201671        (특)KT휴대폰_삼성갤럭시 A31   무형
# 23    2020-06-01 13:40  20.0  100570  201673          KT휴대폰_삼성갤럭시 노트10   무형
# 24    2020-06-01 13:40  20.0  100570  201671        (특)KT휴대폰_삼성갤럭시 A31   무형
# 25    2020-06-01 14:00  20.0  100570  201673          KT휴대폰_삼성갤럭시 노트10   무형
# ...                ...   ...     ...     ...                       ...  ...
# 2848  2020-06-30 18:40  20.0  100073  200195  삼성화재 행복한파트너 주택상해윤전자(올케어)   무형
# 2849  2020-06-30 19:00  20.0  100073  200195  삼성화재 행복한파트너 주택상해윤전자(올케어)   무형
# 2886   2020-07-01 0:20  20.0  100660  201989           쉴렉스  안마의자 렌탈서비스   무형
# 2887   2020-07-01 0:40  20.0  100660  201989           쉴렉스  안마의자 렌탈서비스   무형
# 2888   2020-07-01 1:00  20.0  100660  201989           쉴렉스  안마의자 렌탈서비스   무형
#
#      price  amount
# 21      -      NaN
# ...

# %%
idx_fl = tt[tt['type'] == "무형"].index
tt = tt.drop(idx_fl)
tt
# Out:
#              datetime   exp   mcode   pcode                      name type  \
# 0     2020-06-01 6:20  20.0  100650  201971           잭필드 남성  반팔셔츠 4종   의류
# 1     2020-06-01 6:40  20.0  100650  201971           잭필드 남성  반팔셔츠 4종   의류
# 2     2020-06-01 7:00  20.0  100650  201971           잭필드 남성  반팔셔츠 4종   의류
# 3     2020-06-01 7:20  20.0  100445  202278      쿠미투니카 쿨 레이시 란쥬쉐이퍼&팬티   속옷
# 4     2020-06-01 7:40  20.0  100445  202278      쿠미투니카 쿨 레이시 란쥬쉐이퍼&팬티   속옷
# ...               ...   ...     ...     ...                       ...  ...
# 2883  2020-07-01 0:10  10.0  100099  200273  [일시불]라쉬반 FC바로셀로나 드로즈 패키지   속옷
# 2884  2020-07-01 0:10  10.0  100099  200272  [무이자]라쉬반 FC바로셀로나 드로즈 패키지   속옷
# 2885  2020-07-01 0:10  10.0  100099  200274        라쉬반 FC바로셀로나 드로즈 8종   속옷
# 2889  2020-07-01 1:20  20.0  100261  200875            아놀드파마 티셔츠레깅스세트   의류
# 2890  2020-07-01 1:40  16.0  100261  200875            아놀드파마 티셔츠레깅스세트   의류
#
#           price  amount
# 0       59,800      NaN
# ...

# %%
tt.loc[tt['type'] == '농수축', 'type'] = 10
tt.loc[tt['type'] == '의류', 'type'] = 9
tt.loc[tt['type'] == '속옷', 'type'] = 8
tt.loc[tt['type'] == '주방', 'type'] = 7
tt.loc[tt['type'] == '이미용', 'type'] = 6
tt.loc[tt['type'] == '잡화', 'type'] = 5
tt.loc[tt['type'] == '생활용품', 'type'] = 4
tt.loc[tt['type'] == '건강기능', 'type'] = 3
tt.loc[tt['type'] == '침구', 'type'] = 2
tt.loc[tt['type'] == '가전', 'type'] = 1
tt.loc[tt['type'] == '가구', 'type'] = 0

# %%
tt['price']  = tt['price'].str.strip()

tt
# Out:
#              datetime   exp   mcode   pcode                      name type  \
# 0     2020-06-01 6:20  20.0  100650  201971           잭필드 남성  반팔셔츠 4종    9
# 1     2020-06-01 6:40  20.0  100650  201971           잭필드 남성  반팔셔츠 4종    9
# 2     2020-06-01 7:00  20.0  100650  201971           잭필드 남성  반팔셔츠 4종    9
# 3     2020-06-01 7:20  20.0  100445  202278      쿠미투니카 쿨 레이시 란쥬쉐이퍼&팬티    8
# 4     2020-06-01 7:40  20.0  100445  202278      쿠미투니카 쿨 레이시 란쥬쉐이퍼&팬티    8
# ...               ...   ...     ...     ...                       ...  ...
# 2883  2020-07-01 0:10  10.0  100099  200273  [일시불]라쉬반 FC바로셀로나 드로즈 패키지    8
# 2884  2020-07-01 0:10  10.0  100099  200272  [무이자]라쉬반 FC바로셀로나 드로즈 패키지    8
# 2885  2020-07-01 0:10  10.0  100099  200274        라쉬반 FC바로셀로나 드로즈 8종    8
# 2889  2020-07-01 1:20  20.0  100261  200875            아놀드파마 티셔츠레깅스세트    9
# 2890  2020-07-01 1:40  16.0  100261  200875            아놀드파마 티셔츠레깅스세트    9
#
#         price  amount
# 0      59,800     NaN
# ...

# %%
tt['price']  = tt['price'].str.replace(",","")

tt
# Out:
#              datetime   exp   mcode   pcode                      name type  \
# 0     2020-06-01 6:20  20.0  100650  201971           잭필드 남성  반팔셔츠 4종    9
# 1     2020-06-01 6:40  20.0  100650  201971           잭필드 남성  반팔셔츠 4종    9
# 2     2020-06-01 7:00  20.0  100650  201971           잭필드 남성  반팔셔츠 4종    9
# 3     2020-06-01 7:20  20.0  100445  202278      쿠미투니카 쿨 레이시 란쥬쉐이퍼&팬티    8
# 4     2020-06-01 7:40  20.0  100445  202278      쿠미투니카 쿨 레이시 란쥬쉐이퍼&팬티    8
# ...               ...   ...     ...     ...                       ...  ...
# 2883  2020-07-01 0:10  10.0  100099  200273  [일시불]라쉬반 FC바로셀로나 드로즈 패키지    8
# 2884  2020-07-01 0:10  10.0  100099  200272  [무이자]라쉬반 FC바로셀로나 드로즈 패키지    8
# 2885  2020-07-01 0:10  10.0  100099  200274        라쉬반 FC바로셀로나 드로즈 8종    8
# 2889  2020-07-01 1:20  20.0  100261  200875            아놀드파마 티셔츠레깅스세트    9
# 2890  2020-07-01 1:40  16.0  100261  200875            아놀드파마 티셔츠레깅스세트    9
#
#        price  amount
# 0      59800     NaN
# 1      59800     NaN
# ...

# %%
tt[['price']] = tt[['price']].apply(pd.to_numeric)
tt
# Out:
#              datetime   exp   mcode   pcode                      name type  \
# 0     2020-06-01 6:20  20.0  100650  201971           잭필드 남성  반팔셔츠 4종    9
# 1     2020-06-01 6:40  20.0  100650  201971           잭필드 남성  반팔셔츠 4종    9
# 2     2020-06-01 7:00  20.0  100650  201971           잭필드 남성  반팔셔츠 4종    9
# 3     2020-06-01 7:20  20.0  100445  202278      쿠미투니카 쿨 레이시 란쥬쉐이퍼&팬티    8
# 4     2020-06-01 7:40  20.0  100445  202278      쿠미투니카 쿨 레이시 란쥬쉐이퍼&팬티    8
# ...               ...   ...     ...     ...                       ...  ...
# 2883  2020-07-01 0:10  10.0  100099  200273  [일시불]라쉬반 FC바로셀로나 드로즈 패키지    8
# 2884  2020-07-01 0:10  10.0  100099  200272  [무이자]라쉬반 FC바로셀로나 드로즈 패키지    8
# 2885  2020-07-01 0:10  10.0  100099  200274        라쉬반 FC바로셀로나 드로즈 8종    8
# 2889  2020-07-01 1:20  20.0  100261  200875            아놀드파마 티셔츠레깅스세트    9
# 2890  2020-07-01 1:40  16.0  100261  200875            아놀드파마 티셔츠레깅스세트    9
#
#        price  amount
# 0      59800     NaN
# 1      59800     NaN
# ...

# %%
tt['datetime'] = tt['datetime'].apply(lambda x: pd.to_datetime(str(x), format='%Y-%m-%d %H:%M'))
tt
# Out:
#                 datetime   exp   mcode   pcode                      name type  \
# 0    2020-06-01 06:20:00  20.0  100650  201971           잭필드 남성  반팔셔츠 4종    9
# 1    2020-06-01 06:40:00  20.0  100650  201971           잭필드 남성  반팔셔츠 4종    9
# 2    2020-06-01 07:00:00  20.0  100650  201971           잭필드 남성  반팔셔츠 4종    9
# 3    2020-06-01 07:20:00  20.0  100445  202278      쿠미투니카 쿨 레이시 란쥬쉐이퍼&팬티    8
# 4    2020-06-01 07:40:00  20.0  100445  202278      쿠미투니카 쿨 레이시 란쥬쉐이퍼&팬티    8
# ...                  ...   ...     ...     ...                       ...  ...
# 2883 2020-07-01 00:10:00  10.0  100099  200273  [일시불]라쉬반 FC바로셀로나 드로즈 패키지    8
# 2884 2020-07-01 00:10:00  10.0  100099  200272  [무이자]라쉬반 FC바로셀로나 드로즈 패키지    8
# 2885 2020-07-01 00:10:00  10.0  100099  200274        라쉬반 FC바로셀로나 드로즈 8종    8
# 2889 2020-07-01 01:20:00  20.0  100261  200875            아놀드파마 티셔츠레깅스세트    9
# 2890 2020-07-01 01:40:00  16.0  100261  200875            아놀드파마 티셔츠레깅스세트    9
#
#        price  amount
# ...

# %%
df1=df1.drop(['Unnamed: 0'],axis=1)
df1
# Out:
#                   datetime   exp   mcode   pcode            name type   price  \
# 0      2019-01-01 06:00:00  20.0  100346  201072   테이트 남성 셀린니트3종   의류   39900
# 1      2019-01-01 06:00:00  20.0  100346  201079   테이트 여성 셀린니트3종   의류   39900
# 2      2019-01-01 06:20:00  20.0  100346  201072   테이트 남성 셀린니트3종   의류   39900
# 3      2019-01-01 06:20:00  20.0  100346  201079   테이트 여성 셀린니트3종   의류   39900
# 4      2019-01-01 06:40:00  20.0  100346  201072   테이트 남성 셀린니트3종   의류   39900
# ...                    ...   ...     ...     ...             ...  ...     ...
# 35374  2019-12-31 23:40:00  20.0  100448  201391   일시불쿠첸압력밥솥 6인용   주방  148000
# 35375  2020-01-01 00:00:00  20.0  100448  201383  무이자쿠첸압력밥솥 10인용   주방  178000
# 35376  2020-01-01 00:00:00  20.0  100448  201390  일시불쿠첸압력밥솥 10인용   주방  168000
# 35377  2020-01-01 00:00:00  20.0  100448  201384   무이자쿠첸압력밥솥 6인용   주방  158000
# 35378  2020-01-01 00:00:00  20.0  100448  201391   일시불쿠첸압력밥솥 6인용   주방  148000
#
#             amount        sale
# ...

# %%
a=df1['sale'].groupby(df1['exp']).count()
a
# Out:
# exp
# 2.0         1
# 3.0         6
# 5.0         5
# 7.0         6
# 9.0         1
# 10.0      804
# 11.0        4
# 12.0        4
# 13.0       67
# 14.0        2
# 15.0      435
# 16.0      115
# 17.0      160
# 18.0        4
# 19.0        3
# 20.0    31353
# 22.0        4
# 23.0        9
# 25.0        6
# 26.0       12
# 27.0        2
# 30.0     2374
# 40.0        2
# Name: sale, dtype: int64

# %%
a=pd.DataFrame(a)
a=a.reset_index()
figure,(ax1)=plt.subplots(nrows=1,ncols=1)
figure.set_size_inches(18,8)
sns.barplot(data=a,x="exp",y="sale")
# Out:
# <AxesSubplot:xlabel='exp', ylabel='sale'>

# %%
grouped = tt.groupby('exp')

# %%
q=grouped.count()['price']
q=pd.DataFrame(q)
q=q.reset_index()
figure,(ax1)=plt.subplots(nrows=1,ncols=1)
figure.set_size_inches(18,8)
sns.barplot(data=q,x="exp",y="price")
# Out:
# <AxesSubplot:xlabel='exp', ylabel='price'>

# %%
df1['datetime'] = df1['datetime'].apply(lambda x: pd.to_datetime(str(x), format='%Y-%m-%d %H:%M'))

# %%
df1["year"] = df1["datetime"].dt.year
df1["month"] = df1["datetime"].dt.month
df1["day"] = df1["datetime"].dt.day
df1["hour"] = df1["datetime"].dt.hour
df1["minute"] = df1["datetime"].dt.minute
df1["second"] = df1["datetime"].dt.second
df1["dayofweek"] = df1["datetime"].dt.dayofweek
df1.shape
# Out:
# (35379, 16)

# %%
tt["year"] =tt["datetime"].dt.year
tt["month"] =tt["datetime"].dt.month
tt["day"] = tt["datetime"].dt.day
tt["hour"] = tt["datetime"].dt.hour
tt["minute"] = tt["datetime"].dt.minute
tt["second"] = tt["datetime"].dt.second
tt["dayofweek"] = tt["datetime"].dt.dayofweek
tt.shape
# Out:
# (2716, 15)

# %%
df1.loc[df1['type'] == '농수축', 'type'] = 10
df1.loc[df1['type'] == '의류', 'type'] = 9
df1.loc[df1['type'] == '속옷', 'type'] = 8
df1.loc[df1['type'] == '주방', 'type'] = 7
df1.loc[df1['type'] == '이미용', 'type'] = 6
df1.loc[df1['type'] == '잡화', 'type'] = 5
df1.loc[df1['type'] == '생활용품', 'type'] = 4
df1.loc[df1['type'] == '건강기능', 'type'] = 3
df1.loc[df1['type'] == '침구', 'type'] = 2
df1.loc[df1['type'] == '가전', 'type'] = 1
df1.loc[df1['type'] == '가구', 'type'] = 0

# %%
df1
# Out:
#                  datetime   exp   mcode   pcode            name type   price  \
# 0     2019-01-01 06:00:00  20.0  100346  201072   테이트 남성 셀린니트3종    9   39900
# 1     2019-01-01 06:00:00  20.0  100346  201079   테이트 여성 셀린니트3종    9   39900
# 2     2019-01-01 06:20:00  20.0  100346  201072   테이트 남성 셀린니트3종    9   39900
# 3     2019-01-01 06:20:00  20.0  100346  201079   테이트 여성 셀린니트3종    9   39900
# 4     2019-01-01 06:40:00  20.0  100346  201072   테이트 남성 셀린니트3종    9   39900
# ...                   ...   ...     ...     ...             ...  ...     ...
# 35374 2019-12-31 23:40:00  20.0  100448  201391   일시불쿠첸압력밥솥 6인용    7  148000
# 35375 2020-01-01 00:00:00  20.0  100448  201383  무이자쿠첸압력밥솥 10인용    7  178000
# 35376 2020-01-01 00:00:00  20.0  100448  201390  일시불쿠첸압력밥솥 10인용    7  168000
# 35377 2020-01-01 00:00:00  20.0  100448  201384   무이자쿠첸압력밥솥 6인용    7  158000
# 35378 2020-01-01 00:00:00  20.0  100448  201391   일시불쿠첸압력밥솥 6인용    7  148000
#
# ...

# %%
tt
# Out:
#                 datetime   exp   mcode   pcode                      name type  \
# 0    2020-06-01 06:20:00  20.0  100650  201971           잭필드 남성  반팔셔츠 4종    9
# 1    2020-06-01 06:40:00  20.0  100650  201971           잭필드 남성  반팔셔츠 4종    9
# 2    2020-06-01 07:00:00  20.0  100650  201971           잭필드 남성  반팔셔츠 4종    9
# 3    2020-06-01 07:20:00  20.0  100445  202278      쿠미투니카 쿨 레이시 란쥬쉐이퍼&팬티    8
# 4    2020-06-01 07:40:00  20.0  100445  202278      쿠미투니카 쿨 레이시 란쥬쉐이퍼&팬티    8
# ...                  ...   ...     ...     ...                       ...  ...
# 2883 2020-07-01 00:10:00  10.0  100099  200273  [일시불]라쉬반 FC바로셀로나 드로즈 패키지    8
# 2884 2020-07-01 00:10:00  10.0  100099  200272  [무이자]라쉬반 FC바로셀로나 드로즈 패키지    8
# 2885 2020-07-01 00:10:00  10.0  100099  200274        라쉬반 FC바로셀로나 드로즈 8종    8
# 2889 2020-07-01 01:20:00  20.0  100261  200875            아놀드파마 티셔츠레깅스세트    9
# 2890 2020-07-01 01:40:00  16.0  100261  200875            아놀드파마 티셔츠레깅스세트    9
#
# ...

# %%
holiday=[]

# 열에 추가할 각 행을 For로 순회합니다, 
for row in tt['dayofweek']: 
    if row == "5": 
        holiday.append('1') 
    elif row == "6": 
        holiday.append('1')
    else:
        holiday.append('0')
tt['holiday'] = holiday

# %%
tt
# Out:
#                 datetime   exp   mcode   pcode                      name type  \
# 0    2020-06-01 06:20:00  20.0  100650  201971           잭필드 남성  반팔셔츠 4종    9
# 1    2020-06-01 06:40:00  20.0  100650  201971           잭필드 남성  반팔셔츠 4종    9
# 2    2020-06-01 07:00:00  20.0  100650  201971           잭필드 남성  반팔셔츠 4종    9
# 3    2020-06-01 07:20:00  20.0  100445  202278      쿠미투니카 쿨 레이시 란쥬쉐이퍼&팬티    8
# 4    2020-06-01 07:40:00  20.0  100445  202278      쿠미투니카 쿨 레이시 란쥬쉐이퍼&팬티    8
# ...                  ...   ...     ...     ...                       ...  ...
# 2883 2020-07-01 00:10:00  10.0  100099  200273  [일시불]라쉬반 FC바로셀로나 드로즈 패키지    8
# 2884 2020-07-01 00:10:00  10.0  100099  200272  [무이자]라쉬반 FC바로셀로나 드로즈 패키지    8
# 2885 2020-07-01 00:10:00  10.0  100099  200274        라쉬반 FC바로셀로나 드로즈 8종    8
# 2889 2020-07-01 01:20:00  20.0  100261  200875            아놀드파마 티셔츠레깅스세트    9
# 2890 2020-07-01 01:40:00  16.0  100261  200875            아놀드파마 티셔츠레깅스세트    9
#
# ...

# %%
holiday=[]

# 열에 추가할 각 행을 For로 순회합니다, 
for row in df1['dayofweek']: 
    if row == "5": 
        holiday.append('1') 
    elif row == "6": 
        holiday.append('1')
    else:
        holiday.append('0')
df1['holiday'] = holiday

# %%
ex=[]
#40분 미만은 1, 41분~45분은 2, 46~50은 3, 51~55는 4 56~60은 5, 61~65는 6 67 
for row in df1['exp']: 
    if row <10 : 
        ex.append('10분 미만') 
    elif row>=10 and row<15 : 
        ex.append('10~14')
    elif row>=15 and row<20 : 
        ex.append('15~19')
    elif row>=20 and row<25 : 
        ex.append('20~24')
    elif row>=25 and row<30 : 
        ex.append('25~29')
    else:
        ex.append('30분 초과')
        
df1['exp2'] =ex

# %%
ex=[]
#40분 미만은 1, 41분~45분은 2, 46~50은 3, 51~55는 4 56~60은 5, 61~65는 6 67 
for row in tt['exp']: 
    if row <10 : 
        ex.append('10분 미만') 
    elif row>=10 and row<15 : 
        ex.append('10~14')
    elif row>=15 and row<20 : 
        ex.append('15~19')
    elif row>=20 and row<25 : 
        ex.append('20~24')
    elif row>=25 and row<30 : 
        ex.append('25~29')
    else:
        ex.append('30분 초과')
        
tt['exp2'] =ex

# %%
e=df1['sale'].groupby(df1['exp2']).count()
e=pd.DataFrame(e)
e=e.sort_values(by='sale',ascending=False)
e
# Out:
#          sale
# exp2
# 20~24   31366
# 30분 초과   2376
# 10~14     881
# 15~19     717
# 25~29      20
# 10분 미만     19

# %%
r=tt['price'].groupby(tt['exp2']).count()
r=pd.DataFrame(r)
r=r.sort_values(by='price',ascending=False)
r
# Out:
#         price
# exp2
# 20~24    2383
# 30분 초과    144
# 10~14     125
# 15~19      60
# 10분 미만      4

# %%
df1.loc[df1['exp2'] == '20~24', 'exp2'] = 6
df1.loc[df1['exp2'] == '30분 초과', 'exp2'] = 5
df1.loc[df1['exp2'] == '10~14', 'exp2'] = 4
df1.loc[df1['exp2'] == '15~19', 'exp2'] = 3
df1.loc[df1['exp2'] == '25~29', 'exp2'] = 2
df1.loc[df1['exp2'] == '10분 미만', 'exp2'] = 1

# %%
tt.loc[tt['exp2'] == '20~24', 'exp2'] = 6
tt.loc[tt['exp2'] == '30분 초과', 'exp2'] = 5
tt.loc[tt['exp2'] == '10~14', 'exp2'] = 4
tt.loc[tt['exp2'] == '15~19', 'exp2'] = 3
tt.loc[tt['exp2'] == '25~29', 'exp2'] = 2
tt.loc[tt['exp2'] == '10분 미만', 'exp2'] = 1

# %%
feature_names = ['exp','mcode','price','year','month','day','hour','minute','second','dayofweek','type','holiday','exp2']

feature_names
# Out:
# ['exp',
#  'mcode',
#  'price',
#  'year',
#  'month',
#  'day',
#  'hour',
#  'minute',
#  'second',
#  'dayofweek',
#  'type',
#  'holiday',
#  'exp2']

# %%
X_a= df1[feature_names]

print(X_a.shape)
X_a.head()
# Out:
# (35379, 13)
#     exp   mcode  price  year  month  day  hour  minute  second  dayofweek  \
# 0  20.0  100346  39900  2019      1    1     6       0       0          1
# 1  20.0  100346  39900  2019      1    1     6       0       0          1
# 2  20.0  100346  39900  2019      1    1     6      20       0          1
# 3  20.0  100346  39900  2019      1    1     6      20       0          1
# 4  20.0  100346  39900  2019      1    1     6      40       0          1
#
#   type holiday exp2
# 0    9       0    6
# 1    9       0    6
# 2    9       0    6
# 3    9       0    6
# 4    9       0    6

# %%
X_b = tt[feature_names]

print(X_b.shape)
X_b.head()
# Out:
# (2716, 13)
#     exp   mcode  price  year  month  day  hour  minute  second  dayofweek  \
# 0  20.0  100650  59800  2020      6    1     6      20       0          0
# 1  20.0  100650  59800  2020      6    1     6      40       0          0
# 2  20.0  100650  59800  2020      6    1     7       0       0          0
# 3  20.0  100445  69900  2020      6    1     7      20       0          0
# 4  20.0  100445  69900  2020      6    1     7      40       0          0
#
#   type holiday exp2
# 0    9       0    6
# 1    9       0    6
# 2    9       0    6
# 3    8       0    6
# 4    8       0    6

# %%
label_name = "sale"

y_a = df1[label_name]

print(y_a.shape)
y_a.head()
# Out:
# (35379,)
# 0     52.606516
# 1    109.548872
# 2     81.754386
# 3    174.310777
# 4    167.218045
# Name: sale, dtype: float64

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

k_fold = KFold(n_splits=10, shuffle=True, random_state=0)

# %%
from sklearn.ensemble import RandomForestRegressor

max_depth_list = []

model = RandomForestRegressor(n_estimators=100,
                              n_jobs=-1,
                              random_state=0)
model
# Out:
# RandomForestRegressor(n_jobs=-1, random_state=0)

# %%
# 학습시킴, 피팅(옷을 맞출 때 사용하는 피팅을 생각함) - 피처와 레이블을 넣어주면 알아서 학습함
model.fit(X_a, y_a)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-143-ab6872e7f8c8> in <module>
#       1 # 학습시킴, 피팅(옷을 맞출 때 사용하는 피팅을 생각함) - 피처와 레이블을 넣어주면 알아서 학습함
# ----> 2 model.fit(X_a, y_a)
#
# c:\users\hyeyo\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     302             )
#     303         X, y = self._validate_data(X, y, multi_output=True,
# --> 304                                    accept_sparse="csc", dtype=DTYPE)
#     305         if sample_weight is not None:
#     306             sample_weight = _check_sample_weight(sample_weight, X)
#
# c:\users\hyeyo\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# ...

# %%
# 예측
predictions = model.predict(X_b)

print(predictions.shape)
predictions[0:10]
# Out:
# (2716,)
# array([213.81373007, 349.29577808, 333.51917862, 394.67954443,
#        571.8331127 , 246.48536916, 475.77177515, 786.70423794,
#        345.35686236, 258.76293743])

# %%
fig,(ax1,ax2)= plt.subplots(ncols=2)
fig.set_size_inches(12,5)
sns.distplot(y_a,ax=ax1,bins=50)
ax1.set(title="a")
sns.distplot(predictions,ax=ax2,bins=50)
ax2.set(title="b")
# Out:
# [Text(0.5, 1.0, 'b')]

# %%
predictions
pd.DataFrame(predictions)
# Out:
#                0
# 0     213.813730
# 1     349.295778
# 2     333.519179
# 3     394.679544
# 4     571.833113
# ...          ...
# 2711  228.876239
# 2712  218.788336
# 2713  218.788336
# 2714  140.882680
# 2715  138.680589
#
# [2716 rows x 1 columns]

# %%
tt['sale']=predictions
tt
# Out:
#                 datetime   exp   mcode   pcode                      name type  \
# 0    2020-06-01 06:20:00  20.0  100650  201971           잭필드 남성  반팔셔츠 4종    9
# 1    2020-06-01 06:40:00  20.0  100650  201971           잭필드 남성  반팔셔츠 4종    9
# 2    2020-06-01 07:00:00  20.0  100650  201971           잭필드 남성  반팔셔츠 4종    9
# 3    2020-06-01 07:20:00  20.0  100445  202278      쿠미투니카 쿨 레이시 란쥬쉐이퍼&팬티    8
# 4    2020-06-01 07:40:00  20.0  100445  202278      쿠미투니카 쿨 레이시 란쥬쉐이퍼&팬티    8
# ...                  ...   ...     ...     ...                       ...  ...
# 2883 2020-07-01 00:10:00  10.0  100099  200273  [일시불]라쉬반 FC바로셀로나 드로즈 패키지    8
# 2884 2020-07-01 00:10:00  10.0  100099  200272  [무이자]라쉬반 FC바로셀로나 드로즈 패키지    8
# 2885 2020-07-01 00:10:00  10.0  100099  200274        라쉬반 FC바로셀로나 드로즈 8종    8
# 2889 2020-07-01 01:20:00  20.0  100261  200875            아놀드파마 티셔츠레깅스세트    9
# 2890 2020-07-01 01:40:00  16.0  100261  200875            아놀드파마 티셔츠레깅스세트    9
#
# ...

# %%
tt['amount'] = tt['price']*tt['sale']
tt
# Out:
#                 datetime   exp   mcode   pcode                      name type  \
# 0    2020-06-01 06:20:00  20.0  100650  201971           잭필드 남성  반팔셔츠 4종    9
# 1    2020-06-01 06:40:00  20.0  100650  201971           잭필드 남성  반팔셔츠 4종    9
# 2    2020-06-01 07:00:00  20.0  100650  201971           잭필드 남성  반팔셔츠 4종    9
# 3    2020-06-01 07:20:00  20.0  100445  202278      쿠미투니카 쿨 레이시 란쥬쉐이퍼&팬티    8
# 4    2020-06-01 07:40:00  20.0  100445  202278      쿠미투니카 쿨 레이시 란쥬쉐이퍼&팬티    8
# ...                  ...   ...     ...     ...                       ...  ...
# 2883 2020-07-01 00:10:00  10.0  100099  200273  [일시불]라쉬반 FC바로셀로나 드로즈 패키지    8
# 2884 2020-07-01 00:10:00  10.0  100099  200272  [무이자]라쉬반 FC바로셀로나 드로즈 패키지    8
# 2885 2020-07-01 00:10:00  10.0  100099  200274        라쉬반 FC바로셀로나 드로즈 8종    8
# 2889 2020-07-01 01:20:00  20.0  100261  200875            아놀드파마 티셔츠레깅스세트    9
# 2890 2020-07-01 01:40:00  16.0  100261  200875            아놀드파마 티셔츠레깅스세트    9
#
# ...

# %%
tt.to_excel("하.xlsx")
